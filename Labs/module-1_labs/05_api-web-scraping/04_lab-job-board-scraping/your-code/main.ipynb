# %% [markdown]
# # Job Board Scraping Lab
#
# In this lab you will first see a minimal but fully functional code snippet to scrape the LinkedIn Job Search webpage. You will then work on top of the example code and complete several chanllenges.
#
# ### Some Resources
#
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %%
#from datetime import datetime   
soup.find(class_="result-card__contents")

# %%
# Import the required libraries
import pandas as pd
from bs4 import BeautifulSoup
import requests

"""
This function searches job posts from LinkedIn and converts the results into a dataframe.
"""
def scrape_linkedin_job_search(keywords):
    
    # Define the base url to be scraped.
    # All uppercase variable name signifies this is a constant and its value should never unchange
    BASE_URL = 'https://www.linkedin.com/jobs/search/?'
    
    # Assemble the full url with parameters
    scrape_url = ''.join([BASE_URL, 'keywords=', keywords])

    # Create a request to get the data from the server 
    page = requests.get(scrape_url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Create an empty dataframe with the columns consisting of the information you want to capture
    columns = ['Title', 'Company', 'Location']
    data = pd.DataFrame(columns=columns)

    # Retrieve HTML code from the webpage. Parse the HTML into a list of "cards".
    # Then in each job card, extract the job title, company, and location data.
    titles = []
    companies = []
    locations = []
    for card in soup.select("div.result-card__contents"):
        title = card.findChild("h3", recursive=False)
        company = card.findChild("h4", recursive=False)
        location = card.findChild("span", attrs={"class": "job-result-card__location"}, recursive=True)
        titles.append(title.string)
        companies.append(company.string)
        locations.append(location.string)
    
    # Inject job titles, companies, and locations into the empty dataframe
    zipped = zip(titles, companies, locations)
    for z in list(zipped):
        data=data.append({'Title' : z[0] , 'Company' : z[1], 'Location': z[2]} , ignore_index=True)
    
    # Return dataframe
    return data

# %%
# Example to call the function

results = scrape_linkedin_job_search('data%20analysis')
results
# Out:
#                                           Title  \
# 0                    Data Science and Analytics
# 1                        Data Analyst - Chicago
# 2                                  Data Analyst
# 3                                  Data Analyst
# 4                    Analyst, Data and Analysis
# 5                                  DATA ANALYST
# 6   Fraud Intelligence, Data Operations Analyst
# 7        Data Analytics Associate, CrossInstall
# 8                      Data Engineer, Analytics
# 9                   Data Analyst In - CO8494523
# 10                   Analyst, Data and Analysis
# 11                      Data Scientist (Remote)
# 12                                 Data Analyst
# 13   Data Analyst - Internal Analytics Platform
# 14                 Staff Business Data Analysis
# 15                      Data Analysis Associate
# 16                                 Data Analyst
# 17              Data Analyst - Mobile Analytics
# 18                          DATA ANALYST INTERN
# 19                                 Data Analyst
# 20     Data Analyst - Remote Position! - Dallas
# 21          Quantitative Trading Analyst Intern
# 22                               Data Analyst I
# 23                                 Data Analyst
# 24                                 Data Analyst
#
#                            Company                         Location
# 0         Thermo Fisher Scientific                     Carlsbad, CA
# 1                       SpiderRock                      Chicago, IL
# 2              Shoe Carnival, Inc.                     Columbia, SC
# 3            CapTech Ventures, Inc                    Charlotte, NC
# 4                    Digitas India                       Boston, MA
# 5                    Registry Ally                       Austin, TX
# 6                        White Ops  New York City Metropolitan Area
# 7                    General Mills                San Francisco, CA
# 8                         Facebook                     New York, NY
# 9        American Medical Response            Greenwood Village, CO
# 10           Digitas North America                       Boston, MA
# 11   Kraken Digital Asset Exchange                      Chicago, IL
# 12      BlueWave Resource Partners                      Atlanta, GA
# 13                         Datadog                     New York, NY
# 14                          Intuit                    San Diego, CA
# 15                        Boom Lab                      Atlanta, GA
# 16                         Intrado                     Longmont, CO
# 17                Affine Analytics                  Los Angeles, CA
# 18                            CARE                      Atlanta, GA
# 19                       Instapage                San Francisco, CA
# 20            Seasoned Recruitment                       Dallas, TX
# 21                             DRW                      Chicago, IL
# 22  Massachusetts General Hospital                  Charlestown, NH
# 23             Booz Allen Hamilton                    Arlington, VA
# 24                Aditi Consulting                     Chandler, AZ

# %% [markdown]
# ## Challenge 1
#
# The first challenge for you is to update the `scrape_linkedin_job_search` function by adding a new parameter called `num_pages`. This will allow you to search more than 25 jobs with this function. Suggested steps:
#
# 1. Go to https://www.linkedin.com/jobs/search/?keywords=data%20analysis in your browser.
# 1. Scroll down the left panel and click the page 2 link. Look at how the URL changes and identify the page offset parameter.
# 1. Add `num_pages` as a new param to the `scrape_linkedin_job_search` function. Update the function code so that it uses a "for" loop to retrieve several pages of search results.
# 1. Test your new function by scraping 5 pages of the search results.
#
# Hint: Prepare for the case where there are less than 5 pages of search results. Your function should be robust enough to **not** trigger errors. Simply skip making additional searches and return all results if the search already reaches the end.

# %%
# your code here
def scrape_linkedin_job_search(keywords, num_pages):
    
    # Define the base url to be scraped.
    # All uppercase variable name signifies this is a constant and its value should never unchange
    BASE_URL = 'https://www.linkedin.com/jobs/search/?'
    
    # Create an empty dataframe with the columns consisting of the information you want to capture
    columns = ['Title', 'Company', 'Location']
    data = pd.DataFrame(columns=columns)

    # Retrieve HTML code from the webpage. Parse the HTML into a list of "cards".
    # Then in each job card, extract the job title, company, and location data.
    titles = []
    companies = []
    locations = []
    
    for num in range(num_pages):
        # Assemble the full url with parameters
        scrape_url = ''.join([BASE_URL, 'keywords=', keywords, "&start=", str(num * 25)])

        # Create a request to get the data from the server 
        page = requests.get(scrape_url)
        soup = BeautifulSoup(page.text, 'html.parser')

    
        for card in soup.select("div.result-card__contents"):
            title = card.findChild("h3", recursive=False)
            company = card.findChild("h4", recursive=False)
            location = card.findChild("span", 
                                      attrs={"class": "job-result-card__location"}, recursive=True)
            titles.append(title.string)
            companies.append(company.string)
            locations.append(location.string)
    
    # Inject job titles, companies, and locations into the empty dataframe
    zipped = zip(titles, companies, locations)
    for z in list(zipped):
        data=data.append({'Title' : z[0] , 'Company' : z[1], 'Location': z[2]} , ignore_index=True)
    
    # Return dataframe
    return data
scrape_linkedin_job_search("data%20analysis", 2)
# Out:
#                                           Title  \
# 0                    Data Science and Analytics
# 1                        Data Analyst - Chicago
# 2                                  Data Analyst
# 3                                  Data Analyst
# 4                    Analyst, Data and Analysis
# 5                                  DATA ANALYST
# 6   Fraud Intelligence, Data Operations Analyst
# 7        Data Analytics Associate, CrossInstall
# 8                      Data Engineer, Analytics
# 9                   Data Analyst In - CO8494523
# 10                   Analyst, Data and Analysis
# 11                      Data Scientist (Remote)
# 12                                 Data Analyst
# 13   Data Analyst - Internal Analytics Platform
# 14                 Staff Business Data Analysis
# 15                      Data Analysis Associate
# 16                                 Data Analyst
# 17              Data Analyst - Mobile Analytics
# 18                          DATA ANALYST INTERN
# 19                                 Data Analyst
# 20     Data Analyst - Remote Position! - Dallas
# 21          Quantitative Trading Analyst Intern
# 22                               Data Analyst I
# 23                                 Data Analyst
# 24                                 Data Analyst
# 25                   Data Science and Analytics
# 26                       Data Analyst - Chicago
# 27                                 Data Analyst
# 28                                 Data Analyst
# 29                   Analyst, Data and Analysis
# 30                                 DATA ANALYST
# 31  Fraud Intelligence, Data Operations Analyst
# 32       Data Analytics Associate, CrossInstall
# 33                     Data Engineer, Analytics
# 34                  Data Analyst In - CO8494523
# 35                   Analyst, Data and Analysis
# 36                      Data Scientist (Remote)
# 37                                 Data Analyst
# 38   Data Analyst - Internal Analytics Platform
# 39                 Staff Business Data Analysis
# 40                      Data Analysis Associate
# 41                                 Data Analyst
# 42              Data Analyst - Mobile Analytics
# 43                          DATA ANALYST INTERN
# 44                                 Data Analyst
# 45     Data Analyst - Remote Position! - Dallas
# 46          Quantitative Trading Analyst Intern
# 47                               Data Analyst I
# 48                                 Data Analyst
# 49                                 Data Analyst
#
#                            Company                         Location
# 0         Thermo Fisher Scientific                     Carlsbad, CA
# 1                       SpiderRock                      Chicago, IL
# 2              Shoe Carnival, Inc.                     Columbia, SC
# 3            CapTech Ventures, Inc                    Charlotte, NC
# 4                    Digitas India                       Boston, MA
# 5                    Registry Ally                       Austin, TX
# 6                        White Ops  New York City Metropolitan Area
# 7                    General Mills                San Francisco, CA
# 8                         Facebook                     New York, NY
# 9        American Medical Response            Greenwood Village, CO
# 10           Digitas North America                       Boston, MA
# 11   Kraken Digital Asset Exchange                      Chicago, IL
# 12      BlueWave Resource Partners                      Atlanta, GA
# 13                         Datadog                     New York, NY
# 14                          Intuit                    San Diego, CA
# 15                        Boom Lab                      Atlanta, GA
# 16                         Intrado                     Longmont, CO
# 17                Affine Analytics                  Los Angeles, CA
# 18                            CARE                      Atlanta, GA
# 19                       Instapage                San Francisco, CA
# 20            Seasoned Recruitment                       Dallas, TX
# 21                             DRW                      Chicago, IL
# 22  Massachusetts General Hospital                  Charlestown, NH
# 23             Booz Allen Hamilton                    Arlington, VA
# 24                Aditi Consulting                     Chandler, AZ
# 25        Thermo Fisher Scientific                     Carlsbad, CA
# 26                      SpiderRock                      Chicago, IL
# 27             Shoe Carnival, Inc.                     Columbia, SC
# 28           CapTech Ventures, Inc                    Charlotte, NC
# 29                   Digitas India                       Boston, MA
# 30                   Registry Ally                       Austin, TX
# 31                       White Ops  New York City Metropolitan Area
# 32                   General Mills                San Francisco, CA
# 33                        Facebook                     New York, NY
# 34       American Medical Response            Greenwood Village, CO
# 35           Digitas North America                       Boston, MA
# 36   Kraken Digital Asset Exchange                      Chicago, IL
# 37      BlueWave Resource Partners                      Atlanta, GA
# 38                         Datadog                     New York, NY
# 39                          Intuit                    San Diego, CA
# 40                        Boom Lab                      Atlanta, GA
# 41                         Intrado                     Longmont, CO
# 42                Affine Analytics                  Los Angeles, CA
# 43                            CARE                      Atlanta, GA
# 44                       Instapage                San Francisco, CA
# 45            Seasoned Recruitment                       Dallas, TX
# 46                             DRW                      Chicago, IL
# 47  Massachusetts General Hospital                  Charlestown, NH
# 48             Booz Allen Hamilton                    Arlington, VA
# 49                Aditi Consulting                     Chandler, AZ

# %% [markdown]
# ## Challenge 2
#
# Further improve your function so that it can search jobs in a specific country. Add the 3rd param to your function called `country`. The steps are identical to those in Challange 1.

# %%
# your code here
def scrape_linkedin_job_search(keywords, num_pages, country):
    
    # Define the base url to be scraped.
    # All uppercase variable name signifies this is a constant and its value should never unchange
    BASE_URL = 'https://www.linkedin.com/jobs/search/?'
    
    # Create an empty dataframe with the columns consisting of the information you want to capture
    columns = ['Title', 'Company', 'Location']
    data = pd.DataFrame(columns=columns)

    # Retrieve HTML code from the webpage. Parse the HTML into a list of "cards".
    # Then in each job card, extract the job title, company, and location data.
    titles = []
    companies = []
    locations = []
    
    for num in range(num_pages):
        # Assemble the full url with parameters
        scrape_url = ''.join([BASE_URL, 
                              'keywords=', keywords, 
                              "&start=", str(num * 25),
                              "&location=", country])

        # Create a request to get the data from the server 
        page = requests.get(scrape_url)
        soup = BeautifulSoup(page.text, 'html.parser')

    
        for card in soup.select("div.result-card__contents"):
            title = card.findChild("h3", recursive=False)
            company = card.findChild("h4", recursive=False)
            location = card.findChild("span", 
                                      attrs={"class": "job-result-card__location"}, recursive=True)
            titles.append(title.string)
            companies.append(company.string)
            locations.append(location.string)
    
    # Inject job titles, companies, and locations into the empty dataframe
    zipped = zip(titles, companies, locations)
    for z in list(zipped):
        data=data.append({'Title' : z[0] , 'Company' : z[1], 'Location': z[2]} , ignore_index=True)
    
    # Return dataframe
    return data
scrape_linkedin_job_search("data%20analysis", 2, "Netherlands")
# Out:
#                                                 Title  \
# 0          Data Analyst (Amsterdam/Remote) - IamExpat
# 1      Analyst, Data Management and Analysis (Remote)
# 2                     Data Analyst (Amsterdam/Remote)
# 3                               Manager Data Analysis
# 4                    Data Officer at Risk and Finance
# 5                  Stage Data Analysis & Visualisatie
# 6                                        Data Analyst
# 7                                        Data Analyst
# 8                                  Data/Brand Analyst
# 9                                        Data Analyst
# 10  Internship | Business Intelligence & Data Anal...
# 11                                Global Data Analyst
# 12          Technical Research Analyst (Data Science)
# 13                     Associate: Big data Analytics
# 14                                     Data Scientist
# 15                               Data Analyst Scoober
# 16                     Intern Data Science Consultant
# 17                                       Data Analist
# 18            Risk Assurance Data Analytics Associate
# 19                                     Data Scientist
# 20                                Intern Data Science
# 21                R&D Modelling Statistics Specialist
# 22                                 Fault Data Analyst
# 23                               Quantitative Analyst
# 24  Internship: Business & Data Analytics of Risk ...
# 25         Data Analyst (Amsterdam/Remote) - IamExpat
# 26     Analyst, Data Management and Analysis (Remote)
# 27                    Data Analyst (Amsterdam/Remote)
# 28                              Manager Data Analysis
# 29                   Data Officer at Risk and Finance
# 30                 Stage Data Analysis & Visualisatie
# 31                                       Data Analyst
# 32                                       Data Analyst
# 33                                 Data/Brand Analyst
# 34                                       Data Analyst
# 35  Internship | Business Intelligence & Data Anal...
# 36                                Global Data Analyst
# 37          Technical Research Analyst (Data Science)
# 38                     Associate: Big data Analytics
# 39                                     Data Scientist
# 40                               Data Analyst Scoober
# 41                     Intern Data Science Consultant
# 42                                       Data Analist
# 43            Risk Assurance Data Analytics Associate
# 44                                     Data Scientist
# 45                                Intern Data Science
# 46                R&D Modelling Statistics Specialist
# 47                                 Fault Data Analyst
# 48                               Quantitative Analyst
# 49  Internship: Business & Data Analytics of Risk ...
#
#                           Company  \
# 0                        IamExpat
# 1   Tent Partnership for Refugees
# 2                  Orange Quarter
# 3              Visser & Van Baars
# 4                   ING Nederland
# 5              ABN AMRO Bank N.V.
# 6                      Freshheads
# 7                         Cycleon
# 8                       Patagonia
# 9                          Tiqets
# 10                HousingAnywhere
# 11                         Danone
# 12                           SKIM
# 13               YGroup Companies
# 14                        Catella
# 15                   Takeaway.com
# 16                   Sia Partners
# 17                         Brunel
# 18                  PwC Nederland
# 19                          INREV
# 20                      AkzoNobel
# 21           JACOBS DOUWE EGBERTS
# 22                         Thales
# 23                   NewForesight
# 24                        Philips
# 25                       IamExpat
# 26  Tent Partnership for Refugees
# 27                 Orange Quarter
# 28             Visser & Van Baars
# 29                  ING Nederland
# 30             ABN AMRO Bank N.V.
# 31                     Freshheads
# 32                        Cycleon
# 33                      Patagonia
# 34                         Tiqets
# 35                HousingAnywhere
# 36                         Danone
# 37                           SKIM
# 38               YGroup Companies
# 39                        Catella
# 40                   Takeaway.com
# 41                   Sia Partners
# 42                         Brunel
# 43                  PwC Nederland
# 44                          INREV
# 45                      AkzoNobel
# 46           JACOBS DOUWE EGBERTS
# 47                         Thales
# 48                   NewForesight
# 49                        Philips
#
#                                         Location
# 0          Amsterdam, North Holland, Netherlands
# 1          Amsterdam, North Holland, Netherlands
# 2             Nederland, Overijssel, Netherlands
# 3                     South Holland, Netherlands
# 4          Amsterdam, North Holland, Netherlands
# 5          Amsterdam, North Holland, Netherlands
# 6            Tilburg, North Brabant, Netherlands
# 7                           Utrecht, Netherlands
# 8          Amsterdam, North Holland, Netherlands
# 9          Amsterdam, North Holland, Netherlands
# 10         Rotterdam, South Holland, Netherlands
# 11         Hoofddorp, North Holland, Netherlands
# 12         Rotterdam, South Holland, Netherlands
# 13         Amsterdam, North Holland, Netherlands
# 14              Maastricht, Limburg, Netherlands
# 15         Amsterdam, North Holland, Netherlands
# 16         Amsterdam, North Holland, Netherlands
# 17         Amsterdam, North Holland, Netherlands
# 18         Amsterdam, North Holland, Netherlands
# 19  Koog aan de Zaan, North Holland, Netherlands
# 20        Sassenheim, South Holland, Netherlands
# 21                 Utrecht, Utrecht, Netherlands
# 22              Hengelo, Overijssel, Netherlands
# 23                 Utrecht, Utrecht, Netherlands
# 24         Amsterdam, North Holland, Netherlands
# 25         Amsterdam, North Holland, Netherlands
# 26         Amsterdam, North Holland, Netherlands
# 27            Nederland, Overijssel, Netherlands
# 28                    South Holland, Netherlands
# 29         Amsterdam, North Holland, Netherlands
# 30         Amsterdam, North Holland, Netherlands
# 31           Tilburg, North Brabant, Netherlands
# 32                          Utrecht, Netherlands
# 33         Amsterdam, North Holland, Netherlands
# 34         Amsterdam, North Holland, Netherlands
# 35         Rotterdam, South Holland, Netherlands
# 36         Hoofddorp, North Holland, Netherlands
# 37         Rotterdam, South Holland, Netherlands
# 38         Amsterdam, North Holland, Netherlands
# 39              Maastricht, Limburg, Netherlands
# 40         Amsterdam, North Holland, Netherlands
# 41         Amsterdam, North Holland, Netherlands
# 42         Amsterdam, North Holland, Netherlands
# 43         Amsterdam, North Holland, Netherlands
# 44  Koog aan de Zaan, North Holland, Netherlands
# 45        Sassenheim, South Holland, Netherlands
# 46                 Utrecht, Utrecht, Netherlands
# 47              Hengelo, Overijssel, Netherlands
# 48                 Utrecht, Utrecht, Netherlands
# 49         Amsterdam, North Holland, Netherlands

# %% [markdown]
# ## Challenge 3
#
# Add the 4th param called `num_days` to your function to allow it to search jobs posted in the past X days. Note that in the LinkedIn job search the searched timespan is specified with the following param:
#
# ```
# f_TPR=r259200
# ```
#
# The number part in the param value is the number of seconds. 259,200 seconds equal to 3 days. You need to convert `num_days` to number of seconds and supply that info to LinkedIn job search.

# %%
# your code here
# your code here
def scrape_linkedin_job_search(keywords, num_pages, country, num_days):
    
    # Define the base url to be scraped.
    # All uppercase variable name signifies this is a constant and its value should never unchange
    BASE_URL = 'https://www.linkedin.com/jobs/search/?'
    
    # Number of days
    num_days *= 86400
    
    # Create an empty dataframe with the columns consisting of the information you want to capture
    columns = ['Title', 'Company', 'Location']
    data = pd.DataFrame(columns=columns)

    # Retrieve HTML code from the webpage. Parse the HTML into a list of "cards".
    # Then in each job card, extract the job title, company, and location data.
    titles = []
    companies = []
    locations = []
    
    for num in range(num_pages):
        # Assemble the full url with parameters
        scrape_url = ''.join([BASE_URL, 
                              'keywords=', keywords, 
                              "&f_TPR=r", str(num_days),
                              "&start=", str(num * 25),
                              "&location=", country])

        # Create a request to get the data from the server 
        page = requests.get(scrape_url)
        soup = BeautifulSoup(page.text, 'html.parser')

    
        for card in soup.select("div.result-card__contents"):
            title = card.findChild("h3", recursive=False)
            company = card.findChild("h4", recursive=False)
            location = card.findChild("span", 
                                      attrs={"class": "job-result-card__location"}, recursive=True)
            titles.append(title.string)
            companies.append(company.string)
            locations.append(location.string)
    
    # Inject job titles, companies, and locations into the empty dataframe
    zipped = zip(titles, companies, locations)
    for z in list(zipped):
        data=data.append({'Title' : z[0] , 'Company' : z[1], 'Location': z[2]} , ignore_index=True)
    
    # Return dataframe
    return data
scrape_linkedin_job_search("data%20analysis", 2, "United%20States", 1)
# Out:
#                                           Title  \
# 0                    Data Science and Analytics
# 1                        Data Analyst - Chicago
# 2                                  Data Analyst
# 3                                  Data Analyst
# 4                    Analyst, Data and Analysis
# 5                                  DATA ANALYST
# 6   Fraud Intelligence, Data Operations Analyst
# 7        Data Analytics Associate, CrossInstall
# 8                      Data Engineer, Analytics
# 9                   Data Analyst In - CO8494523
# 10                   Analyst, Data and Analysis
# 11                      Data Scientist (Remote)
# 12                                 Data Analyst
# 13   Data Analyst - Internal Analytics Platform
# 14                 Staff Business Data Analysis
# 15                      Data Analysis Associate
# 16                                 Data Analyst
# 17              Data Analyst - Mobile Analytics
# 18                          DATA ANALYST INTERN
# 19                                 Data Analyst
# 20     Data Analyst - Remote Position! - Dallas
# 21          Quantitative Trading Analyst Intern
# 22                               Data Analyst I
# 23                                 Data Analyst
# 24                                 Data Analyst
# 25                   Data Science and Analytics
# 26                       Data Analyst - Chicago
# 27                                 Data Analyst
# 28                                 Data Analyst
# 29                   Analyst, Data and Analysis
# 30                                 DATA ANALYST
# 31  Fraud Intelligence, Data Operations Analyst
# 32       Data Analytics Associate, CrossInstall
# 33                     Data Engineer, Analytics
# 34                  Data Analyst In - CO8494523
# 35                   Analyst, Data and Analysis
# 36                      Data Scientist (Remote)
# 37                                 Data Analyst
# 38   Data Analyst - Internal Analytics Platform
# 39                 Staff Business Data Analysis
# 40                      Data Analysis Associate
# 41                                 Data Analyst
# 42              Data Analyst - Mobile Analytics
# 43                          DATA ANALYST INTERN
# 44                                 Data Analyst
# 45     Data Analyst - Remote Position! - Dallas
# 46          Quantitative Trading Analyst Intern
# 47                               Data Analyst I
# 48                                 Data Analyst
# 49                                 Data Analyst
#
#                            Company                         Location
# 0         Thermo Fisher Scientific                     Carlsbad, CA
# 1                       SpiderRock                      Chicago, IL
# 2              Shoe Carnival, Inc.                     Columbia, SC
# 3            CapTech Ventures, Inc                    Charlotte, NC
# 4                    Digitas India                       Boston, MA
# 5                    Registry Ally                       Austin, TX
# 6                        White Ops  New York City Metropolitan Area
# 7                    General Mills                San Francisco, CA
# 8                         Facebook                     New York, NY
# 9        American Medical Response            Greenwood Village, CO
# 10           Digitas North America                       Boston, MA
# 11   Kraken Digital Asset Exchange                      Chicago, IL
# 12      BlueWave Resource Partners                      Atlanta, GA
# 13                         Datadog                     New York, NY
# 14                          Intuit                    San Diego, CA
# 15                        Boom Lab                      Atlanta, GA
# 16                         Intrado                     Longmont, CO
# 17                Affine Analytics                  Los Angeles, CA
# 18                            CARE                      Atlanta, GA
# 19                       Instapage                San Francisco, CA
# 20            Seasoned Recruitment                       Dallas, TX
# 21                             DRW                      Chicago, IL
# 22  Massachusetts General Hospital                  Charlestown, NH
# 23             Booz Allen Hamilton                    Arlington, VA
# 24                Aditi Consulting                     Chandler, AZ
# 25        Thermo Fisher Scientific                     Carlsbad, CA
# 26                      SpiderRock                      Chicago, IL
# 27             Shoe Carnival, Inc.                     Columbia, SC
# 28           CapTech Ventures, Inc                    Charlotte, NC
# 29                   Digitas India                       Boston, MA
# 30                   Registry Ally                       Austin, TX
# 31                       White Ops  New York City Metropolitan Area
# 32                   General Mills                San Francisco, CA
# 33                        Facebook                     New York, NY
# 34       American Medical Response            Greenwood Village, CO
# 35           Digitas North America                       Boston, MA
# 36   Kraken Digital Asset Exchange                      Chicago, IL
# 37      BlueWave Resource Partners                      Atlanta, GA
# 38                         Datadog                     New York, NY
# 39                          Intuit                    San Diego, CA
# 40                        Boom Lab                      Atlanta, GA
# 41                         Intrado                     Longmont, CO
# 42                Affine Analytics                  Los Angeles, CA
# 43                            CARE                      Atlanta, GA
# 44                       Instapage                San Francisco, CA
# 45            Seasoned Recruitment                       Dallas, TX
# 46                             DRW                      Chicago, IL
# 47  Massachusetts General Hospital                  Charlestown, NH
# 48             Booz Allen Hamilton                    Arlington, VA
# 49                Aditi Consulting                     Chandler, AZ

# %% [markdown]
# ## Bonus Challenge
#
# Allow your function to also retrieve the "Seniority Level" of each job searched. Note that the Seniority Level info is not in the initial search results. You need to make a separate search request for each job card based on the `currentJobId` value which you can extract from the job card HTML.
#
# After you obtain the Seniority Level info, update the function and add it to a new column of the returned dataframe.

# %%
# your code here
def scrape_linkedin_job_search(keywords, num_pages=1, num_days=0, country=None):
    
    # Define the base url to be scraped.
    # All uppercase variable name signifies this is a constant and its value should never unchange
    BASE_URL = 'https://www.linkedin.com/jobs/search/?'
    
    # Work on arguments
    country_text = f"&location={country}" if country else ""
    days_text = f"&f_TPR=r{num_days * 86400}" if num_days else ""
    
    # Create an empty dataframe with the columns consisting of the information you want to capture
    columns = ['Title', 'Company', 'Location']
    data = pd.DataFrame(columns=columns)

    # Retrieve HTML code from the webpage. Parse the HTML into a list of "cards".
    # Then in each job card, extract the job title, company, and location data.
    titles = []
    companies = []
    locations = []
    currentJobId = []
    
    for num in range(num_pages):
        # Assemble the full url with parameters
        scrape_url = ''.join([BASE_URL, 
                              'keywords=', keywords,
                              "&start=", str(num * 25),
                              days_text,
                              country_text])

        # Create a request to get the data from the server 
        page = requests.get(scrape_url)
        soup = BeautifulSoup(page.text, 'html.parser')

    
        for card in soup.select("div.result-card__contents"):
            title = card.findChild("h3", recursive=False)
            company = card.findChild("h4", recursive=False)
            location = card.findChild("span", 
                                      attrs={"class": "job-result-card__location"}, recursive=True)
            titles.append(title.string)
            companies.append(company.string)
            locations.append(location.string)
            
            # Get level from next page
            deep_url = card.parent.find("a", class_ = "result-card__full-card-link").get("href")
            deep_page = requests.get(deep_url)
            deep_soup = BeautifulSoup(deep_page.text, 'html.parser')
            level = deep_soup.find(class_="job-criteria__text--criteria").text
            currentJobId.append(level)
    
    # Inject job titles, companies, and locations into the empty dataframe
    zipped = zip(titles, companies, locations, currentJobId)
    for z in list(zipped):
        data=data.append({'Title' : z[0] , 'Company' : z[1], 
                          'Location': z[2], 'Job id': z[3]} , ignore_index=True)
    
    # Return dataframe
    return data
scrape_linkedin_job_search("data%20analysis")
# Out:
#                                           Title  \
# 0                    Data Science and Analytics
# 1                        Data Analyst - Chicago
# 2                                  Data Analyst
# 3                                  Data Analyst
# 4                    Analyst, Data and Analysis
# 5                                  DATA ANALYST
# 6   Fraud Intelligence, Data Operations Analyst
# 7        Data Analytics Associate, CrossInstall
# 8                      Data Engineer, Analytics
# 9                   Data Analyst In - CO8494523
# 10                   Analyst, Data and Analysis
# 11                      Data Scientist (Remote)
# 12                                 Data Analyst
# 13   Data Analyst - Internal Analytics Platform
# 14                 Staff Business Data Analysis
# 15                      Data Analysis Associate
# 16                                 Data Analyst
# 17              Data Analyst - Mobile Analytics
# 18                          DATA ANALYST INTERN
# 19                                 Data Analyst
# 20     Data Analyst - Remote Position! - Dallas
# 21          Quantitative Trading Analyst Intern
# 22                               Data Analyst I
# 23                                 Data Analyst
# 24                                 Data Analyst
#
#                            Company                         Location  \
# 0         Thermo Fisher Scientific                     Carlsbad, CA
# 1                       SpiderRock                      Chicago, IL
# 2              Shoe Carnival, Inc.                     Columbia, SC
# 3            CapTech Ventures, Inc                    Charlotte, NC
# 4                    Digitas India                       Boston, MA
# 5                    Registry Ally                       Austin, TX
# 6                        White Ops  New York City Metropolitan Area
# 7                    General Mills                San Francisco, CA
# 8                         Facebook                     New York, NY
# 9        American Medical Response            Greenwood Village, CO
# 10           Digitas North America                       Boston, MA
# 11   Kraken Digital Asset Exchange                      Chicago, IL
# 12      BlueWave Resource Partners                      Atlanta, GA
# 13                         Datadog                     New York, NY
# 14                          Intuit                    San Diego, CA
# 15                        Boom Lab                      Atlanta, GA
# 16                         Intrado                     Longmont, CO
# 17                Affine Analytics                  Los Angeles, CA
# 18                            CARE                      Atlanta, GA
# 19                       Instapage                San Francisco, CA
# 20            Seasoned Recruitment                       Dallas, TX
# 21                             DRW                      Chicago, IL
# 22  Massachusetts General Hospital                  Charlestown, NH
# 23             Booz Allen Hamilton                    Arlington, VA
# 24                Aditi Consulting                     Chandler, AZ
#
#               Job id
# 0     Not Applicable
# 1        Entry level
# 2        Entry level
# 3        Entry level
# 4        Entry level
# 5   Mid-Senior level
# 6   Mid-Senior level
# 7        Entry level
# 8     Not Applicable
# 9        Entry level
# 10  Mid-Senior level
# 11       Entry level
# 12       Entry level
# 13       Entry level
# 14         Associate
# 15         Associate
# 16       Entry level
# 17  Mid-Senior level
# 18        Internship
# 19  Mid-Senior level
# 20       Entry level
# 21        Internship
# 22         Associate
# 23       Entry level
# 24       Entry level
