# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2
x_label = "x axis"
y_label = "y axis"
z_label = "z axis"
first = "x -- y" 
second = "x -- z"

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)

plt.subplot(1, 2, 1)
plt.plot(x, y, label=first, color="r", linestyle="-")
plt.subplot(1, 2, 2)
plt.plot(x, z, label=second, color="b", linestyle="--")

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)


fig, [ax1, ax2] = plt.subplots(1, 2)
ax1.plot(x, y, color="r", linestyle="-")
ax2.plot(x, z, color="b", linestyle="--")

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here

fig, [ax1, ax2] = plt.subplots(1, 2, figsize=(10,8))
ax1.plot(x, y)
ax1.set_title(first)   

ax2.plot(x, z)
ax2.set_title(second)
# Out:
# Text(0.5, 1.0, 'x -- z')

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here
fig, [ax1, ax2] = plt.subplots(1, 2, figsize=(10,8))
ax1.plot(x, y)
ax1.set_title(first)   
ax1.set_xlabel(x_label)     
ax1.set_ylabel(y_label)   

ax2.plot(x, z)
ax2.set_title(second)   
ax2.set_xlabel(x_label)     
ax2.set_ylabel(z_label)
# Out:
# Text(0, 0.5, 'z axis')

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here
y = x^2
z = np.exp(x)
y_color = "r"
z_color = "b"
fig, ax1 = plt.subplots(figsize=(10,8))
ax1.plot(x, y, color=y_color, linestyle="-")
ax1.set_yscale("linear")
ax1.set_ylabel('linear', color=y_color)
ax1.tick_params(axis='y', labelcolor=y_color)

ax2 = ax1.twinx()
ax2.plot(x, z, color=z_color, linestyle="--")
ax2.set_yscale("log")
ax2.set_ylabel('exp', color=z_color)
ax2.tick_params(axis='y', labelcolor=z_color)

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here
df = pd.read_csv("vehicles.csv")
# df.head()


df.plot(x = "Combined MPG",
        y = "Highway MPG",
        kind = "scatter")

# %%
co2 = df["CO2 Emission Grams/Mile"]
co2.describe()
# Out:
# count    35952.000000
# mean       475.316339
# std        119.060773
# min         37.000000
# 25%        395.000000
# 50%        467.736842
# 75%        555.437500
# max       1269.571429
# Name: CO2 Emission Grams/Mile, dtype: float64

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
# your code here
co2.plot(kind = "box",
       figsize=(12,8))

# %%
fuel = df.set_index(["Model", "Year"])
fuel = fuel["Fuel Barrels/Year"]
fuel.head()
# Out:
# Model                Year
# DJ Po Vehicle 2WD    1984    19.388824
# FJ8c Post Office     1984    25.354615
# Post Office DJ5 2WD  1985    20.600625
# Post Office DJ8 2WD  1985    25.354615
# GNX                  1987    20.600625
# Name: Fuel Barrels/Year, dtype: float64

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# your code here
fuel.plot(kind = "hist",
          figsize=(12,8),
          bins=20)

# %%
df.head()
ft = df.groupby("Fuel Type")
ft.head()
# Out:
#                    Make                         Model  Year  \
# 0            AM General             DJ Po Vehicle 2WD  1984
# 1            AM General              FJ8c Post Office  1984
# 2            AM General           Post Office DJ5 2WD  1985
# 3            AM General           Post Office DJ8 2WD  1985
# 4      ASC Incorporated                           GNX  1987
# ...                 ...                           ...   ...
# 12581              Ford      F150 Dual-fuel 2WD (LPG)  2002
# 12582              Ford      F150 Dual-fuel 2WD (LPG)  2003
# 12583              Ford      F150 Dual-fuel 2WD (LPG)  2004
# 12588              Ford      F150 Dual-fuel 4WD (LPG)  2001
# 13408              Ford  Fusion Energi Plug-in Hybrid  2013
#
#        Engine Displacement  Cylinders                      Transmission  \
# 0                      2.5        4.0                   Automatic 3-spd
# 1                      4.2        6.0                   Automatic 3-spd
# 2                      2.5        4.0                   Automatic 3-spd
# 3                      4.2        6.0                   Automatic 3-spd
# 4                      3.8        6.0                   Automatic 4-spd
# ...                    ...        ...                               ...
# 12581                  5.4        8.0                   Automatic 4-spd
# 12582                  5.4        8.0                   Automatic 4-spd
# 12583                  5.4        8.0                   Automatic 4-spd
# 12588                  5.4        8.0                   Automatic 4-spd
# 13408                  2.0        4.0  Automatic (variable gear ratios)
#
#                        Drivetrain                Vehicle Class  \
# 0                   2-Wheel Drive  Special Purpose Vehicle 2WD
# 1                   2-Wheel Drive  Special Purpose Vehicle 2WD
# 2                Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3                Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4                Rear-Wheel Drive                 Midsize Cars
# ...                           ...                          ...
# 12581            Rear-Wheel Drive   Standard Pickup Trucks 2WD
# 12582            Rear-Wheel Drive   Standard Pickup Trucks 2WD
# 12583            Rear-Wheel Drive   Standard Pickup Trucks 2WD
# 12588  4-Wheel or All-Wheel Drive   Standard Pickup Trucks 4WD
# 13408           Front-Wheel Drive                 Midsize Cars
#
#                          Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  \
# 0                          Regular          19.388824        18           17
# 1                          Regular          25.354615        13           13
# 2                          Regular          20.600625        16           17
# 3                          Regular          25.354615        13           13
# 4                          Premium          20.600625        14           21
# ...                            ...                ...       ...          ...
# 12581          Gasoline or propane          27.467500        11           15
# 12582          Gasoline or propane          21.974000        13           18
# 12583          Gasoline or propane          21.974000        13           18
# 12588          Gasoline or propane          27.467500        11           15
# 13408  Regular Gas and Electricity           4.878704        40           36
#
#        Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0                17               522.764706            1950
# 1                13               683.615385            2550
# 2                16               555.437500            2100
# 3                13               683.615385            2550
# 4                16               555.437500            2550
# ...             ...                      ...             ...
# 12581            12               740.583333            2800
# 12582            15               592.466667            2200
# 12583            15               592.466667            2200
# 12588            12               740.583333            2800
# 13408            38               129.000000             900
#
# [62 rows x 15 columns]

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# your code here
df.plot(x= ,
        y=  "City MPG",
        kind = "bar",
         figsize=(12,8),
bins=20)
