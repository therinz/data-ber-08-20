# %% [markdown]
# # Pandas Project - cleaning shark attacks csv

# %% [markdown]
# ## Workflow determination
# 1. Determine steps to be taken
# 2. Set up csv in pandas and create copy to work with
# 3. Declare helper functions
# 3. Gather information about shape and characteristics of dataframe
# 6. Check data types
# 4. Inspect data
# 9. Check null values
# 5. Change column names
# 8. Remove duplicates
# 10. Remove irrelevant columns
# 11. Convert dates
# 12. Clean data in column
# 12. And then correct data type
# 14. Set new index according to unique tracker
# 15. Export to new csv

# %% [markdown]
# ## Set up
#
#
# First we import the necessary libraries

# %%
import re

import numpy as np
import pandas as pd

from string import punctuation
from datetime import datetime

# %% [markdown]
# Now we declare helper functions

# %%
def clean_col_names(df):
    """Take a dataframe and return sanitized column names."""

    table = str.maketrans(dict.fromkeys(punctuation))
    return [c.lower()
            .strip()
            .translate(table)
            .replace(" ", "_") for c in df.columns]


def cols_missing_value(df):
    """Return fraction of column missing value."""
    
    return ((df.isna().sum())[df.isna().sum() > 0] / len(df)) * 100

def invalid_year(date):
    """Return NaT if not valid year."""
    
    # Doesn't work because of 20 non-cooperating rows
    if date == date:
        if date > datetime.strptime('2020', '%y'):
            return pd.NaT
    return date

def search_and_set(df, col, word, regex=False, lst=[]):
    """Search for term and set correspending rows to value."""
    
    # If lst is set, we use every term therein, otherwise just 
    # set word as first item
        
    if not lst:
        lst = [word]
    
    if regex:
        for item in lst:
            df.loc[df[col].str.contains(
                item, case=False, na=False, regex=True), col] = word
    else:
        for item in lst:
            df.loc[df[col].str.contains(
                item, case=False, na=False), col] = word

def regex_test(txt, pat, needle=False):
    """Return NaN if string contains no space."""
    
    check = re.search(pat, str(txt))
    if check:
        return check.group() if needle else txt
    return np.NaN

# %% [markdown]
# Next we import the csv into pandas and inspect the head

# %%
df_original = pd.read_csv("attacks.csv", encoding="cp1252")
df = df_original.copy()
df.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#           Species           Investigator or Source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1              NaN  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2              NaN  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25         6303.0         NaN         NaN
# 1    2018.06.18         6302.0         NaN         NaN
# 2    2018.06.09         6301.0         NaN         NaN
# 3    2018.06.08         6300.0         NaN         NaN
# 4    2018.06.04         6299.0         NaN         NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Inspect

# %%
# rows and columns
df.shape
# Out:
# (25723, 24)

# %%
# Types of columns
df.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
# Random sample of data
df.sample(20)
# Out:
#         Case Number         Date    Year        Type Country        Area  \
# 2430   1994.07.08.b  08-Jul-1994  1994.0  Unprovoked  BRAZIL  Pernambuco
# 24367           NaN          NaN     NaN         NaN     NaN         NaN
# 18596           NaN          NaN     NaN         NaN     NaN         NaN
# 18859           NaN          NaN     NaN         NaN     NaN         NaN
# 16876           NaN          NaN     NaN         NaN     NaN         NaN
# 19948           NaN          NaN     NaN         NaN     NaN         NaN
# 14535           NaN          NaN     NaN         NaN     NaN         NaN
# 15547           NaN          NaN     NaN         NaN     NaN         NaN
# 15167           NaN          NaN     NaN         NaN     NaN         NaN
# 7516              0          NaN     NaN         NaN     NaN         NaN
# 2645     1990.02.17  17-Feb-1990  1990.0  Unprovoked     USA      Hawaii
# 14678           NaN          NaN     NaN         NaN     NaN         NaN
# 8593              0          NaN     NaN         NaN     NaN         NaN
# 4206     1957.02.24  24-Feb-1957  1957.0  Unprovoked    FIJI   Viti Levu
# 1004   2010.08.02.b  02-Aug-2010  2010.0     Boating     USA  California
# 11425           NaN          NaN     NaN         NaN     NaN         NaN
# 9644            NaN          NaN     NaN         NaN     NaN         NaN
# 6750              0          NaN     NaN         NaN     NaN         NaN
# 13555           NaN          NaN     NaN         NaN     NaN         NaN
# 21055           NaN          NaN     NaN         NaN     NaN         NaN
#
#                                                 Location  \
# 2430                                  Boa Viagem, Recife
# 24367                                                NaN
# 18596                                                NaN
# 18859                                                NaN
# 16876                                                NaN
# 19948                                                NaN
# 14535                                                NaN
# 15547                                                NaN
# 15167                                                NaN
# 7516                                                 NaN
# 2645    Mokapu, Kane'ohe Marine Air Corps Station, O'ahu
# 14678                                                NaN
# 8593                                                 NaN
# 4206                                         Suva Harbor
# 1004   Near oil rig Hondo, 5 nm from Gaviota, Santa B...
# 11425                                                NaN
# 9644                                                 NaN
# 6750                                                 NaN
# 13555                                                NaN
# 21055                                                NaN
#
#                           Activity                     Name Sex   ...  \
# 2430                       Surfing  Sandro Paulo dos Santos    M  ...
# 24367                          NaN                      NaN  NaN  ...
# 18596                          NaN                      NaN  NaN  ...
# 18859                          NaN                      NaN  NaN  ...
# 16876                          NaN                      NaN  NaN  ...
# 19948                          NaN                      NaN  NaN  ...
# 14535                          NaN                      NaN  NaN  ...
# 15547                          NaN                      NaN  NaN  ...
# 15167                          NaN                      NaN  NaN  ...
# 7516                           NaN                      NaN  NaN  ...
# 2645   Scuba diving & spearfishing            Roy T. Tanaka    M  ...
# 14678                          NaN                      NaN  NaN  ...
# 8593                           NaN                      NaN  NaN  ...
# 4206                  Spearfishing                Sami Bale    M  ...
# 1004                      Kayaking          Duane Strosaker    M  ...
# 11425                          NaN                      NaN  NaN  ...
# 9644                           NaN                      NaN  NaN  ...
# 6750                           NaN                      NaN  NaN  ...
# 13555                          NaN                      NaN  NaN  ...
# 21055                          NaN                      NaN  NaN  ...
#
#                                                 Species   \
# 2430                                                 NaN
# 24367                                                NaN
# 18596                                                NaN
# 18859                                                NaN
# 16876                                                NaN
# 19948                                                NaN
# 14535                                                NaN
# 15547                                                NaN
# 15167                                                NaN
# 7516                                                 NaN
# 2645   Two sharks seen in vicinity: 2.4 m & 4.25 m  [...
# 14678                                                NaN
# 8593                                                 NaN
# 4206                                                 NaN
# 1004                                    White shark, 15'
# 11425                                                NaN
# 9644                                                 NaN
# 6750                                                 NaN
# 13555                                                NaN
# 21055                                                NaN
#
#                                   Investigator or Source  \
# 2430                                            JCOnline
# 24367                                                NaN
# 18596                                                NaN
# 18859                                                NaN
# 16876                                                NaN
# 19948                                                NaN
# 14535                                                NaN
# 15547                                                NaN
# 15167                                                NaN
# 7516                                                 NaN
# 2645      J. Borg, pp.78-79; L. Taylor (1993) pp.110-111
# 14678                                                NaN
# 8593                                                 NaN
# 4206   NOTE: V.M. Coppleson (1962), p.253, records th...
# 1004                                    R. Collier, GSAF
# 11425                                                NaN
# 9644                                                 NaN
# 6750                                                 NaN
# 13555                                                NaN
# 21055                                                NaN
#
#                                           pdf  \
# 2430   1994.07.08.b-SandroPaulosDosSantos.pdf
# 24367                                     NaN
# 18596                                     NaN
# 18859                                     NaN
# 16876                                     NaN
# 19948                                     NaN
# 14535                                     NaN
# 15547                                     NaN
# 15167                                     NaN
# 7516                                      NaN
# 2645                    1990.02.17-Tanaka.pdf
# 14678                                     NaN
# 8593                                      NaN
# 4206                      1957.02.24-Bale.pdf
# 1004               2010.08.02.b-Strosaker.pdf
# 11425                                     NaN
# 9644                                      NaN
# 6750                                      NaN
# 13555                                     NaN
# 21055                                     NaN
#
#                                             href formula  \
# 2430   http://sharkattackfile.net/spreadsheets/pdf_di...
# 24367                                                NaN
# 18596                                                NaN
# 18859                                                NaN
# 16876                                                NaN
# 19948                                                NaN
# 14535                                                NaN
# 15547                                                NaN
# 15167                                                NaN
# 7516                                                 NaN
# 2645   http://sharkattackfile.net/spreadsheets/pdf_di...
# 14678                                                NaN
# 8593                                                 NaN
# 4206   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1004   http://sharkattackfile.net/spreadsheets/pdf_di...
# 11425                                                NaN
# 9644                                                 NaN
# 6750                                                 NaN
# 13555                                                NaN
# 21055                                                NaN
#
#                                                     href Case Number.1  \
# 2430   http://sharkattackfile.net/spreadsheets/pdf_di...  1994.07.08.b
# 24367                                                NaN           NaN
# 18596                                                NaN           NaN
# 18859                                                NaN           NaN
# 16876                                                NaN           NaN
# 19948                                                NaN           NaN
# 14535                                                NaN           NaN
# 15547                                                NaN           NaN
# 15167                                                NaN           NaN
# 7516                                                 NaN           NaN
# 2645   http://sharkattackfile.net/spreadsheets/pdf_di...    1990.02.17
# 14678                                                NaN           NaN
# 8593                                                 NaN           NaN
# 4206   http://sharkattackfile.net/spreadsheets/pdf_di...    1957.02.24
# 1004   http://sharkattackfile.net/spreadsheets/pdf_di...  2010.08.02.b
# 11425                                                NaN           NaN
# 9644                                                 NaN           NaN
# 6750                                                 NaN           NaN
# 13555                                                NaN           NaN
# 21055                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 2430   1994.07.08.b         3873.0         NaN         NaN
# 24367           NaN            NaN         NaN         NaN
# 18596           NaN            NaN         NaN         NaN
# 18859           NaN            NaN         NaN         NaN
# 16876           NaN            NaN         NaN         NaN
# 19948           NaN            NaN         NaN         NaN
# 14535           NaN            NaN         NaN         NaN
# 15547           NaN            NaN         NaN         NaN
# 15167           NaN            NaN         NaN         NaN
# 7516            NaN            NaN         NaN         NaN
# 2645     1990.02.17         3658.0         NaN         NaN
# 14678           NaN            NaN         NaN         NaN
# 8593            NaN            NaN         NaN         NaN
# 4206     1957.02.24         2097.0         NaN         NaN
# 1004   2010.08.02.b         5299.0         NaN         NaN
# 11425           NaN            NaN         NaN         NaN
# 9644            NaN            NaN         NaN         NaN
# 6750            NaN            NaN         NaN         NaN
# 13555           NaN            NaN         NaN         NaN
# 21055           NaN            NaN         NaN         NaN
#
# [20 rows x 24 columns]

# %%
# Columns with NA values
cols_missing_value(df)
# Out:
# Case Number               66.170353
# Date                      75.500525
# Year                      75.508300
# Type                      75.516075
# Country                   75.694903
# Area                      77.269370
# Location                  77.599813
# Activity                  77.615364
# Name                      76.316915
# Sex                       77.697003
# Age                       86.506240
# Injury                    75.609377
# Fatal (Y/N)               77.595926
# Time                      88.539439
# Species                   86.533453
# Investigator or Source    75.566614
# pdf                       75.500525
# href formula              75.504412
# href                      75.500525
# Case Number.1             75.500525
# Case Number.2             75.500525
# original order            75.473312
# Unnamed: 22               99.996112
# Unnamed: 23               99.992225
# dtype: float64

# %% [markdown]
# ### A few observations
#    - column names contain punctuation, spaces and capitals
#    - case number seems to be same as Date, and Year is a pary of previous two
#    - many rows have no data at all
#    - pdf is part of href formula, which in turn is equal to href
#    - last 2 columns have no name and out of 25723 only 1 or 2 rows have a value
#    - age and species values are mainly missing

# %% [markdown]
# ## General cleanup
#
# Now we know a little about our data set, we are going to start cleaning. First we tackle the big stuff.

# %%
# Clean up column names
df.columns = clean_col_names(df)
df.columns
# Out:
# Index(['case_number', 'date', 'year', 'type', 'country', 'area', 'location',
#        'activity', 'name', 'sex', 'age', 'injury', 'fatal_yn', 'time',
#        'species', 'investigator_or_source', 'pdf', 'href_formula', 'href',
#        'case_number1', 'case_number2', 'original_order', 'unnamed_22',
#        'unnamed_23'],
#       dtype='object')

# %%
# Remove duplicate rows
df.drop_duplicates(inplace=True)

# %%
cols_missing_value(df)
# Out:
# case_number                0.031686
# date                       0.158428
# year                       0.190114
# type                       0.221800
# country                    0.950570
# area                       7.366920
# location                   8.713561
# activity                   8.776933
# name                       3.485425
# sex                        9.109632
# age                       45.009506
# injury                     0.602028
# fatal_yn                   8.697719
# time                      53.295311
# species                   45.120406
# investigator_or_source     0.427757
# pdf                        0.158428
# href_formula               0.174271
# href                       0.158428
# case_number1               0.158428
# case_number2               0.158428
# original_order             0.047529
# unnamed_22                99.984157
# unnamed_23                99.968314
# dtype: float64

# %% [markdown]
# ## Type
#
# We start cleaning more in depth by looking at the type column.

# %%
# We check the values for 'type'
df["type"].value_counts(dropna=False)
# Out:
# Unprovoked      4595
# Provoked         574
# Invalid          547
# Sea Disaster     239
# Boating          203
# Boat             137
# NaN               14
# Questionable       2
# Boatomg            1
# Name: type, dtype: int64

# %%
# Change invalid and questionable to NaN
df["type"].replace(["Invalid", "Questionable"], np.nan, inplace=True)

# And merge boating
df["type"].replace(["Boat", "Boatomg"], "Boating", inplace=True)

df["type"].value_counts(dropna=False)
# Out:
# Unprovoked      4595
# Provoked         574
# NaN              563
# Boating          341
# Sea Disaster     239
# Name: type, dtype: int64

# %% [markdown]
# ## Clearing redundant columns
#
# Since case_number is same as date, and original_order is a unique index, we will drop all 3 case_number columns. Also, the href_formula and pdf column are duplicate to href. Finally we remove the redundant unnamed columns

# %%
to_drop = ["case_number", "year", "pdf", 
           "href_formula", "case_number1", 
           "case_number2", "unnamed_22", "unnamed_23"]
df = df.drop(axis = 1, columns = to_drop)
df.head()
# Out:
#           date        type    country             area  \
# 0  25-Jun-2018     Boating        USA       California
# 1  18-Jun-2018  Unprovoked        USA          Georgia
# 2  09-Jun-2018         NaN        USA           Hawaii
# 3  08-Jun-2018  Unprovoked  AUSTRALIA  New South Wales
# 4  04-Jun-2018    Provoked     MEXICO           Colima
#
#                          location     activity             name sex  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F   11
# 2                    Habush, Oahu      Surfing      John Denges   M   48
# 3              Arrawarra Headland      Surfing             male   M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos    M  NaN
#
#                                               injury fatal_yn           time  \
# 0  No injury to occupant, outrigger canoe and pad...        N          18h00
# 1                         Minor injury to left thigh        N  14h00  -15h00
# 2       Injury to left lower leg from surfboard skeg        N          07h45
# 3                          Minor injury to lower leg        N            NaN
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT        N            NaN
#
#            species          investigator_or_source  \
# 0      White shark                R. Collier, GSAF
# 1              NaN  K.McMurray, TrackingSharks.com
# 2              NaN  K.McMurray, TrackingSharks.com
# 3        2 m shark                  B. Myatt, GSAF
# 4  Tiger shark, 3m                       A .Kipper
#
#                                                 href  original_order
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...          6303.0
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...          6302.0
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...          6301.0
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...          6300.0
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...          6299.0

# %% [markdown]
# ## Removing bogus rows
#
# When rows hold no real data, we remove them

# %%
# If there is no location we don't want to keep the row
cols_missing_value(df)
# Out:
# date                       0.158428
# type                       8.919518
# country                    0.950570
# area                       7.366920
# location                   8.713561
# activity                   8.776933
# name                       3.485425
# sex                        9.109632
# age                       45.009506
# injury                     0.602028
# fatal_yn                   8.697719
# time                      53.295311
# species                   45.120406
# investigator_or_source     0.427757
# href                       0.158428
# original_order             0.047529
# dtype: float64

# %%
# There are still many rows with very little data. We will drop all that have less than 2 columns of data
df.dropna(thresh=2, inplace=True)
df.dropna(subset=["country"], inplace=True)

# %%
df.sample(30)
# Out:
#                       date          type               country  \
# 4798           24-Mar-1939    Unprovoked      PAPUA NEW GUINEA
# 761            24-Jul-2012           NaN                   USA
# 6153                  1755    Unprovoked                SWEDEN
# 5136           03-Jan-1927    Unprovoked             AUSTRALIA
# 2177           25-Jul-1998    Unprovoked                   USA
# 2388           18-May-1995    Unprovoked             AUSTRALIA
# 4311                  1955      Provoked                  CUBA
# 4843           16-Aug-1937           NaN                TURKEY
# 2799              Dec-1986    Unprovoked         NEW CALEDONIA
# 2604           03-Apr-1991    Unprovoked                   USA
# 4098           27-Apr-1959           NaN             AUSTRALIA
# 1505           01-Feb-2006       Boating                   USA
# 3566           31-Jul-1966    Unprovoked                   USA
# 3129           07-Jan-1978    Unprovoked          SOUTH AFRICA
# 3360           19-Jul-1971    Unprovoked                   USA
# 3099              May 1979    Unprovoked         NEW CALEDONIA
# 95             02-Sep-2017    Unprovoked                   USA
# 1426              Oct-2006    Unprovoked          GULF OF ADEN
# 4766           31-Mar-1940    Unprovoked          SOUTH AFRICA
# 3280           07-Jan-1974    Unprovoked          SOUTH AFRICA
# 4731           07-Dec-1941  Sea Disaster  SOUTH ATLANTIC OCEAN
# 3735           16-Oct-1963    Unprovoked                   USA
# 4664           21-Nov-1943    Unprovoked          SOUTH AFRICA
# 870            04-Sep-2011    Unprovoked                   USA
# 5916           11-May-1870    Unprovoked                 INDIA
# 2569           06-Jan-1992    Unprovoked             MAURITIUS
# 1105  Reported 24-Jul-2009    Unprovoked                 KENYA
# 3422           22-Aug-1969      Provoked                   USA
# 2988           27-Feb-1982    Unprovoked                   USA
# 3790           30-Sep-1962    Unprovoked   BRITISH WEST INDIES
#
#                                 area                                location  \
# 4798                Central Province                            Port Moresby
# 761                   North Carolina            Ocean Isle, Brunswick County
# 6153  Skagerrak arm of the North Sea                                Bohuslän
# 5136                 New South Wales              Grey’s Point, Port Hacking
# 2177                         Florida        New Smyrna Beach, Volusia County
# 2388               Western Australia               Bernier Island, Shark Bay
# 4311                 Havana Province                                 Cojimar
# 4843                             NaN                                Istanbul
# 2799                             NaN                               I'le Ouen
# 2604                          Hawaii   One'ula Beach Park, 'Ewa Beach, O'ahu
# 4098                 New South Wales                            Maroubra Bay
# 1505                          Hawaii            Off Pu'u Ola'l, Makena, Maui
# 3566                           Texas                  South Jetty, Galveston
# 3129                   KwaZulu-Natal                              Glenashley
# 3360                      California    Point Purisima, Santa Barbara County
# 3099                  North Province                                  Balade
# 95                           Florida        New Smyrna Beach, Volusia County
# 1426         Between Somalia & Yemen                                     NaN
# 4766                   KwaZulu-Natal  Danger Pool, Winkelspruit, South Coast
# 3280                   KwaZulu-Natal                             Amanzimtoti
# 4731                             NaN                                     NaN
# 3735                         Florida        Biltmore Beach, near Panama City
# 4664           Eastern Cape Province                         Kei River Mouth
# 870                           Hawaii                Nimitz State Beach, Oahu
# 5916                      22ºN, 88ºE                        Near Sobah Bazar
# 2569                             NaN                               Mahebourg
# 1105                         Mombasa                          Likoni Channel
# 3422                   Massachusetts             40 miles south of Nantucket
# 2988                         Florida           Hobe Sound, Palm Beach County
# 3790               Grand Turk Island                                Long Cay
#
#                                                activity  \
# 4798                                   Dived for a coin
# 761                                                 NaN
# 6153                                                NaN
# 5136                                           Swimming
# 2177                                            Surfing
# 2388                                                NaN
# 4311                                            Fishing
# 4843                                           Swimming
# 2799                                       Spearfishing
# 2604                               Sitting on surfboard
# 4098                                       Spearfishing
# 1505                                           Kayaking
# 3566                            Diving for sand dollars
# 3129                                            Surfing
# 3360                          Hookah diving (submerged)
# 3099                                                NaN
# 95                                              Surfing
# 1426                                             Murder
# 4766                                     Treading water
# 3280                                           Swimming
# 4731  Torpedoed & burning British  light cruiser wit...
# 3735                              Surf fishing, wading
# 4664                                Swimming with board
# 870                                             Surfing
# 5916                                            Bathing
# 2569                                            Fishing
# 1105                                   Washing his feet
# 3422                                            Fishing
# 2988                                            Surfing
# 3790                                       Spearfishing
#
#                             name  sex  age  \
# 4798                   Raho-Heni    M  NaN
# 761                         male    M   12
# 6153                   Fishermen    M  NaN
# 5136               Mervwyn Allum    M   15
# 2177               Michael Rinto    M   13
# 2388                    Hutchins  NaN  NaN
# 4311                     Romilio    M  NaN
# 4843                        male    M  NaN
# 2799             Maurice Lilloux  NaN  NaN
# 2604               Todd R. Wenke    M  NaN
# 4098               Peter Holland    M   22
# 1505                Dan Lankheit    M   57
# 3566           Robert W. Russell    M   16
# 3129              Laurence Evans    M   17
# 3360                Kenneth Gray    M  NaN
# 3099         Ferdinand Teanyouen    M  NaN
# 95                  Chase Elmore    M   17
# 1426        5 Ethiopian refugees  NaN  NaN
# 4766                    Joe Lees    M   25
# 3280       Cornelius “Les” Pyper    M   33
# 4731                         NaN  NaN  NaN
# 3735            William Cheatham    M   28
# 4664          Richard Richardson    M  NaN
# 870                    M. Filipe  NaN  NaN
# 5916  male, a Hindu confectioner    M   40
# 2569                        male    M  NaN
# 1105                        male    M  NaN
# 3422           Robert Eleniefsky    M   28
# 2988               Richard Bauer    M   18
# 3790              Wesley Vickrey    M   24
#
#                                                  injury fatal_yn       time  \
# 4798                 FATAL, leg severed just below hip         Y        NaN
# 761                       Shark involvement unconfirmed      NaN      11h45
# 6153                                                NaN  UNKNOWN        NaN
# 5136              FATAL, leg bitten from thigh to ankle        Y      11h30
# 2177                                        Calf bitten        N       P.M.
# 2388                                         No details  UNKNOWN        NaN
# 4311  Forearm slashed wrist to elbow by hooked shark...        N        NaN
# 4843                               No injury, no attack      NaN        NaN
# 2799                                   Right leg bitten        N        NaN
# 2604                   Deep lacerations to calf & ankle        N      17h30
# 4098                                    Thigh lacerated      NaN        NaN
# 1505  No injury to occupant; shark bumped the kayak ...        N  Afternoon
# 3566                        Dorsum of right foot grazed        N        NaN
# 3129                      Left leg, ankle & foot bitten        N      12h45
# 3360            Major injuries to head, buttocks & back        N        NaN
# 3099                                              FATAL        Y        NaN
# 95                           Minor injury to right hand        N      10h44
# 1426  FATAL,  beaten & thrown overboard by smugglers...        Y        NaN
# 4766                  FATAL, right thigh & calf bitten         Y      11h00
# 3280                              Knee & calf lacerated        N      14h10
# 4731  Only 170 survived, many of the crew were said ...        Y        NaN
# 3735  Right thigh &  foot bruised, right calf  lacer...        N      17h30
# 4664                               Right foot lacerated        N        NaN
# 870                      No injury, shark bit surfboard        N      13h00
# 5916  3 lacerated irregular wounds on anterior left ...        N        NaN
# 2569                                           Survived        N        NaN
# 1105                                              FATAL        Y        NaN
# 3422       Leg bitten by netted shark PROVOKED INCIDENT        N        NaN
# 2988               Lacerations to left hand and forearm        N        NaN
# 3790                Left thigh & hand & speargun bitten        N      14h30
#
#                                                 species  \
# 4798                                    "a large shark"
# 761                     Shark involvement not confirmed
# 6153                                                NaN
# 5136                                  3.7 m [12'] shark
# 2177                                                NaN
# 2388                                                NaN
# 4311                                   "a little shark"
# 4843                                            Invalid
# 2799                                        Tiger shark
# 2604                     "Shark had a very large girth"
# 4098                              Questionable incident
# 1505                                   12' to 18' shark
# 3566                     Lemon shark or sandtiger shark
# 3129                Thought to involve a blacktip shark
# 3360            White shark, 5.5 m to 6 m [18' to 20']
# 3099                                          2 m shark
# 95                                                  NaN
# 1426                                                NaN
# 4766  White shark, species identity confirmed by too...
# 3280               2 m to 2.5 m [6.75'  to 8.25'] shark
# 4731  Reportedly: oceanic whitetip sharks, blue shar...
# 3735                                       500-lb shark
# 4664                                                NaN
# 870                                                 NaN
# 5916                                                NaN
# 2569                                    Grey reef shark
# 1105                                                NaN
# 3422                                                NaN
# 2988                                     4' to 5' shark
# 3790   Blacktip shark, C. maculipinnis. 1.9 m to 2.1...
#
#                                  investigator_or_source  \
# 4798  The Papuan Villager, March 1939; G.P. Whitley,...
# 761                                   C. Creswell, GSAF
# 6153                                     C. Moore, GSAF
# 5136  V.M. Coppleson.N.21.(1933); V.M. Coppleson (19...
# 2177  S. Petersohn, GSAF; Orlando Sentinel, 7/24/199...
# 2388                                     T. Peake, GSAF
# 4311                                      F. Poli, p.13
# 4843                                     C. Moore. GSAF
# 2799                                         W. Leander
# 2604        J. Borg, p.79; L. Taylor (1993), pp.110-111
# 4098       V.M. Coppleson (1962), p.251; J. Green, p.35
# 1505    R. Collier, GSAF; Honolulu Advertiser, 2/1/2006
# 3566                M. Vorenberg, H.D. Baldridge, p.191
# 3129                W. Pople, G. Charter, B. Davis, NSB
# 3360  D. Miller & R. Collier, R. Collier, pp.51-52; ...
# 3099                                         W. Leander
# 95                              Click Orlando, 9/2/2017
# 1426  United Nations High Commission for Refugees, 1...
# 4766            G. Cawston;  H. Robson, M. Levine, GSAF
# 3280  L. Pyper, J. Bass, G. Charter; B. Davis, M. Le...
# 4731           F. Dennis, pp. 19-20; A. Resciniti, p.90
# 3735                              H.D. Baldridge, p.109
# 4664                                    M. Levine, GSAF
# 870                                  KITV.com, 9/4/2011
# 5916                                    J. Fayrer, M.D.
# 2569                                      D. deSpeville
# 1105                        Standard Digital, 7/24/2009
# 3422                       Portsmouth Herald, 8/23/1969
# 2988                       Palm Beach Post, 3/2/1982
# 3790                              H.D. Baldridge, p.197
#
#                                                    href  original_order
# 4798  http://sharkattackfile.net/spreadsheets/pdf_di...          1505.0
# 761   http://sharkattackfile.net/spreadsheets/pdf_di...          5542.0
# 6153  http://sharkattackfile.net/spreadsheets/pdf_di...           150.0
# 5136  http://sharkattackfile.net/spreadsheets/pdf_di...          1167.0
# 2177  http://sharkattackfile.net/spreadsheets/pdf_di...          4126.0
# 2388  http://sharkattackfile.net/spreadsheets/pdf_di...          3915.0
# 4311  http://sharkattackfile.net/spreadsheets/pdf_di...          1992.0
# 4843  http://sharkattackfile.net/spreadsheets/pdf_di...          1460.0
# 2799  http://sharkattackfile.net/spreadsheets/pdf_di...          3504.0
# 2604  http://sharkattackfile.net/spreadsheets/pdf_di...          3699.0
# 4098  http://sharkattackfile.net/spreadsheets/pdf_di...          2205.0
# 1505  http://sharkattackfile.net/spreadsheets/pdf_di...          4798.0
# 3566  http://sharkattackfile.net/spreadsheets/pdf_di...          2737.0
# 3129  http://sharkattackfile.net/spreadsheets/pdf_di...          3174.0
# 3360  http://sharkattackfile.net/spreadsheets/pdf_di...          2943.0
# 3099  http://sharkattackfile.net/spreadsheets/pdf_di...          3204.0
# 95    http://sharkattackfile.net/spreadsheets/pdf_di...          6208.0
# 1426  http://sharkattackfile.net/spreadsheets/pdf_di...          4877.0
# 4766  http://sharkattackfile.net/spreadsheets/pdf_di...          1537.0
# 3280  http://sharkattackfile.net/spreadsheets/pdf_di...          3023.0
# 4731  http://sharkattackfile.net/spreadsheets/pdf_di...          1572.0
# 3735  http://sharkattackfile.net/spreadsheets/pdf_di...          2568.0
# 4664  http://sharkattackfile.net/spreadsheets/pdf_di...          1639.0
# 870   http://sharkattackfile.net/spreadsheets/pdf_di...          5433.0
# 5916  http://sharkattackfile.net/spreadsheets/pdf_di...           387.0
# 2569  http://sharkattackfile.net/spreadsheets/pdf_di...          3734.0
# 1105  http://sharkattackfile.net/spreadsheets/pdf_di...          5198.0
# 3422  http://sharkattackfile.net/spreadsheets/pdf_di...          2881.0
# 2988  http://sharkattackfile.net/spreadsheets/pdf_di...          3315.0
# 3790  http://sharkattackfile.net/spreadsheets/pdf_di...          2513.0

# %% [markdown]
# ## Date
# Next we look at the date.

# %%
# Change date to datetime column
df.date = pd.to_datetime(df["date"], errors="coerce", )
df.head()
# Out:
#         date        type    country             area  \
# 0 2018-06-25     Boating        USA       California
# 1 2018-06-18  Unprovoked        USA          Georgia
# 2 2018-06-09         NaN        USA           Hawaii
# 3 2018-06-08  Unprovoked  AUSTRALIA  New South Wales
# 4 2018-06-04    Provoked     MEXICO           Colima
#
#                          location     activity             name sex  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F   11
# 2                    Habush, Oahu      Surfing      John Denges   M   48
# 3              Arrawarra Headland      Surfing             male   M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos    M  NaN
#
#                                               injury fatal_yn           time  \
# 0  No injury to occupant, outrigger canoe and pad...        N          18h00
# 1                         Minor injury to left thigh        N  14h00  -15h00
# 2       Injury to left lower leg from surfboard skeg        N          07h45
# 3                          Minor injury to lower leg        N            NaN
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT        N            NaN
#
#            species          investigator_or_source  \
# 0      White shark                R. Collier, GSAF
# 1              NaN  K.McMurray, TrackingSharks.com
# 2              NaN  K.McMurray, TrackingSharks.com
# 3        2 m shark                  B. Myatt, GSAF
# 4  Tiger shark, 3m                       A .Kipper
#
#                                                 href  original_order
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...          6303.0
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...          6302.0
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...          6301.0
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...          6300.0
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...          6299.0

# %%
# Get rid of future dates. Doesn't work because of 20 rows that aren't yet in date format it seems.
#df["date"] = df["date"].apply(invalid_year)
df.date.isna().values.sum()
# Out:
# 821

# %% [markdown]
# ## Activity column
# This column takes a lot more work. There are many different values, more than 1500. We will try to use combine them to bring it down to 120.

# %%
df.activity.value_counts()
# Out:
# Surfing                                                                                    970
# Swimming                                                                                   862
# Fishing                                                                                    431
# Spearfishing                                                                               332
# Bathing                                                                                    160
#                                                                                           ...
# Fell from yardarm of British ship Rover                                                      1
# Shark Fishing                                                                                1
# Attempting to free the shark                                                                 1
# Plane forced down, 3 men on rubber life raft. Put hand over side to feel drift of boat       1
# Goggle-diving for seaweeds, but standing in water                                            1
# Name: activity, Length: 1513, dtype: int64

# %%
# Let's check what values we have in this column
df["activity"].unique()
# Out:
# array(['Paddling', 'Standing', 'Surfing', ...,
#        'Crew swimming alongside their anchored ship',
#        '4 men were bathing', 'Wreck of  large double sailing canoe'],
#       dtype=object)

# %%
# Search and equalize common values in activity column

# Key is category, list in value are search patterns
regex_dict = {"shipwreck": ["wreck", "sea disaster", "battle", 
                            "sunk", "sank", "capsiz", "swamped",
                            "burning", "Fell", "adrift", "washed",
                            "overboard", "thrown", "sink", "swept",
                            "murder", "explosion", "freighter", "tanker",
                            "founder", "steam", "submarine", "torped",
                            "destroy", "collided", "drown", "desert",
                            "accident", "disappear", "dinghy", "raft"],
              "beach activity": [r"sta.*ding", "wading", "walking", 
                                 "gathering", "lying", "splash", "playing",
                                 "wading", "inflat", "sitting"],
              "shark handling": ["shark"],
              "surfing": ["surfboard", r"surf[a-z]?ng", "kite", r"sup\b", 
                          "boardi", "paddling"],
              "aircrash": ["airc", "air disaster", "air/sea disaster", 
                           "airlin", r"air.*force", "plane", "boeing"], 
              "canoeing": [r".*skiing", "canoe", "kayak"],
              "fishing": [r"fish[a-z]*", "hunting", "spear", "netting", "prawn",
                          "harpoo", "lobster", "crab", "collecting", "shrimp",
                          "oyster", "sardine", "hauling", "casting", "catching"],
              "washing": [r"wash[^e]"],
              "swimming": ["swimming", "treading", "dived", r"swim", 
                           "bathing", "floating", "jump", "kneeling"],
              "boating": ["boating", "sailing", "rowing", "cruising", "yacht"],
              "diving": ["diving", "snorkeling", "diver"],
              "research": ["photo", "film", "research", "scient"],
              np.NaN: ["unknown"]}

for k, v in regex_dict.items():
    search_and_set(df, "activity", k, regex=True, lst=v)

# Also we want to set values like unknown to NaN , 
#search_and_set(df, "activity", pd.NA, lst=["unknown"])

# %%
df["activity"].nunique()
# Out:
# 122

# %% [markdown]
# ## Sex column
# This column is fairly straight forward. We can combine into M or F

# %%
# Clean up the column for sex
df["sex"].unique()
# Out:
# array(['F', 'M', nan, 'M ', 'lli', 'N', '.'], dtype=object)

# %%
# Anything that's not F or M will be set to NaN
search_and_set(df, "sex", np.NaN, lst=[r"[^FM]"])

# %% [markdown]
# ## Name column
# We follow a similar process, but need to account for the fact that some names feature a '.' or ','.

# %%
df["name"].value_counts()
# Out:
# male              542
# female             97
# boy                23
# boat               14
# 2 males            14
#                  ...
# Naval aviator       1
# Sabrina Garcia      1
# John Brothers       1
# Gordon Johnson      1
# Carl Nakuina        1
# Name: name, Length: 5196, dtype: int64

# %%
# First change how Jr is written, so we can check for punctuation later
regex_pat = re.compile(r"[,]* jr[.]*")
df["name"] = (df["name"]
              .str.lower()
              .str.strip()
              .str.replace(regex_pat, " jr", regex=True))

# Now remove everything with punctuation
search_and_set(df, "name", np.NaN, regex=True, 
               lst=[r"\d", r"\ba\s[a-z]*", r"male", r"[,:;]"])

# And remove all single 'names'
df["name"] = df["name"].str.title().apply(regex_test, args=(r"[ ]", ))

# %% [markdown]
# ## Age
# For age we decide only to keep values that are 1 or 2 digits. As well we change the dtype to int.

# %%
# Next we clean up the age column
df.age.value_counts()
# Out:
# 17               154
# 18               150
# 19               142
# 20               139
# 15               139
#                 ...
#  30                1
# 13 or 14           1
# 2 to 3 months      1
# 17 & 35            1
# 74                 1
# Name: age, Length: 157, dtype: int64

# %%
# First correct for babies
search_and_set(df, "age", "1", lst=["month"])
# Now if we find 1 or 2 digits we keep that value. 
df["age"] = df["age"].str.strip().apply(regex_test, args=(r"\d{1,2}", True))

# %%
# Now we've cleared bogus values, we can convert to integer
df["age"] = df["age"].fillna(0).astype(int)

# %% [markdown]
# ## Cleaning fatal_yn
# This column is fairly straight forward, and we can just use the method we used earlier as well.

# %%
df.fatal_yn.unique()
# Out:
# array(['N', 'Y', nan, 'M', 'UNKNOWN', '2017', ' N', 'N ', 'y'],
#       dtype=object)

# %%
regex_dict = {np.NaN: ["unknown", "2017"],
         "N": ["n", "m"],
         "Y": ["y"]
        }
for k,v in regex_dict.items():
    search_and_set(df, "fatal_yn", k, regex=True, lst=v)

# %% [markdown]
# ## Setting a new index
#
# If original_order is unique then we can use it as an index

# %%
df["original_order"].value_counts(dropna=False)
# Out:
# 569.0     2
# 3854.0    1
# 725.0     1
# 708.0     1
# 590.0     1
#          ..
# 3106.0    1
# 3080.0    1
# 2812.0    1
# 2712.0    1
# 6272.0    1
# Name: original_order, Length: 6251, dtype: int64

# %%
# There are 2 rows with number 569. The highest value is 6303, so we change one of the 2 to 6304.

df.loc[(df["original_order"] == 569) & (df["type"] == "Unprovoked"), "original_order"] = 6304

# %%
# Getting rid of empty rows
df["original_order"].dropna(inplace=True)

# %%
# We change the column dtype to int
df["original_order"] = df["original_order"].astype(int)

# %%
# Now the original_order is unique, we can use it as an index
df.set_index("original_order", inplace=True)
df.head()
# Out:
#                      date        type    country             area  \
# original_order
# 6303           2018-06-25     Boating        USA       California
# 6302           2018-06-18  Unprovoked        USA          Georgia
# 6301           2018-06-09         NaN        USA           Hawaii
# 6300           2018-06-08  Unprovoked  AUSTRALIA  New South Wales
# 6299           2018-06-04    Provoked     MEXICO           Colima
#
#                                       location        activity           name  \
# original_order
# 6303               Oceanside, San Diego County         surfing    Julie Wolfe
# 6302            St. Simon Island, Glynn County  beach activity            NaN
# 6301                              Habush, Oahu         surfing    John Denges
# 6300                        Arrawarra Headland         surfing            NaN
# 6299                                  La Ticla          diving  Gustavo Ramos
#
#                sex  age                                             injury  \
# original_order
# 6303             F   57  No injury to occupant, outrigger canoe and pad...
# 6302             F   11                         Minor injury to left thigh
# 6301             M   48       Injury to left lower leg from surfboard skeg
# 6300             M    0                          Minor injury to lower leg
# 6299             M    0  Lacerations to leg & hand shark PROVOKED INCIDENT
#
#                fatal_yn           time          species  \
# original_order
# 6303                  N          18h00      White shark
# 6302                  N  14h00  -15h00              NaN
# 6301                  N          07h45              NaN
# 6300                  N            NaN        2 m shark
# 6299                  N            NaN  Tiger shark, 3m
#
#                         investigator_or_source  \
# original_order
# 6303                          R. Collier, GSAF
# 6302            K.McMurray, TrackingSharks.com
# 6301            K.McMurray, TrackingSharks.com
# 6300                            B. Myatt, GSAF
# 6299                                 A .Kipper
#
#                                                              href
# original_order
# 6303            http://sharkattackfile.net/spreadsheets/pdf_di...
# 6302            http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301            http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300            http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299            http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
df.head()
# Out:
#                      date        type    country             area  \
# original_order
# 6303           2018-06-25     Boating        USA       California
# 6302           2018-06-18  Unprovoked        USA          Georgia
# 6301           2018-06-09         NaN        USA           Hawaii
# 6300           2018-06-08  Unprovoked  AUSTRALIA  New South Wales
# 6299           2018-06-04    Provoked     MEXICO           Colima
#
#                                       location        activity           name  \
# original_order
# 6303               Oceanside, San Diego County         surfing    Julie Wolfe
# 6302            St. Simon Island, Glynn County  beach activity            NaN
# 6301                              Habush, Oahu         surfing    John Denges
# 6300                        Arrawarra Headland         surfing            NaN
# 6299                                  La Ticla          diving  Gustavo Ramos
#
#                sex  age                                             injury  \
# original_order
# 6303             F   57  No injury to occupant, outrigger canoe and pad...
# 6302             F   11                         Minor injury to left thigh
# 6301             M   48       Injury to left lower leg from surfboard skeg
# 6300             M    0                          Minor injury to lower leg
# 6299             M    0  Lacerations to leg & hand shark PROVOKED INCIDENT
#
#                fatal_yn           time          species  \
# original_order
# 6303                  N          18h00      White shark
# 6302                  N  14h00  -15h00              NaN
# 6301                  N          07h45              NaN
# 6300                  N            NaN        2 m shark
# 6299                  N            NaN  Tiger shark, 3m
#
#                         investigator_or_source  \
# original_order
# 6303                          R. Collier, GSAF
# 6302            K.McMurray, TrackingSharks.com
# 6301            K.McMurray, TrackingSharks.com
# 6300                            B. Myatt, GSAF
# 6299                                 A .Kipper
#
#                                                              href
# original_order
# 6303            http://sharkattackfile.net/spreadsheets/pdf_di...
# 6302            http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301            http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300            http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299            http://sharkattackfile.net/spreadsheets/pdf_di...
